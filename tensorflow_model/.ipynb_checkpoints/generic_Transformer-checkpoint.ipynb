# %%
list_of_image = []

# %%
for i in range(1,9):
    add = add_base + str(i)+ '.jpeg'
    img = np.asarray(Image.open(add))
    for j in range(0, 8):
        out = transformer(img)
        scipy.misc.imsave('./sample/'+str(i)+ str(j) +'.jpeg',out)
# Out:
# /home/abjb/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
add = add_base
